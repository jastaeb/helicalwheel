# %% [markdown]
# Installation

# %%
# !conda install pip
# !pip install helicalwheel
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Requirement already satisfied: helicalwheel in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (0.1.1)
# Requirement already satisfied: numpy in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from helicalwheel) (2.3.5)
# Requirement already satisfied: pandas in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from helicalwheel) (2.3.3)
# Requirement already satisfied: matplotlib in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from helicalwheel) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from matplotlib->helicalwheel) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->helicalwheel) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from pandas->helicalwheel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jann/miniforge3/envs/naive/lib/python3.14/site-packages (from pandas->helicalwheel) (2025.3)

# %% [markdown]
# Import the helicalwheel package.

# %%
import helicalwheel as hw

# %% [markdown]
# The following code was used to produce the helical wheel figures for the following publication:
# ***insert citation***

# %%
# %% Inputting the sequences  
aap2_seq_wt = "LVWELIRWLQAVAHQWQTIT"
aap2_seq_pm = "AAAEAARAAQAAAHQAQTAT" 


# Check that sequences are of the same length
if len(aap2_seq_wt) != len(aap2_seq_pm):
    raise ValueError("Wild-type and mutant sequences must be of the same length.")
else:
    mut_res = [i != y for i, y in zip(aap2_seq_wt, aap2_seq_pm)]

# %% Creating dataframes with helix coordinates
df_wt=hw.helix_coordinates(aap2_seq_wt)
df_wt_rotated=hw.helix_coordinates(aap2_seq_wt, rotate_deg=180)
df_pm=hw.helix_coordinates(aap2_seq_pm)
df_pm_rotated=hw.helix_coordinates(aap2_seq_pm, rotate_deg=180)

# Adding mutation information to the dataframes
df_wt["mutated"]=mut_res
df_wt_rotated["mutated"]=mut_res
df_pm["mutated"]=mut_res
df_pm_rotated["mutated"]=mut_res

#%% Plotting the helical wheels
first_pos = 21 # position in total protein sequence of first helical residue 

ft1=0
lt1=10
ft2=10
lt2=len(aap2_seq_wt)


# 1. Wild-type AAP2
# Entire helix
wt_plot_1 = hw.helixplot(df_wt, first_pos=first_pos)

# Two individual plots figure assembly
wt_plot_1 = hw.helixplot(df_wt.iloc[ft1:lt1], legend=False, first_pos=first_pos)

wt_plot_1_rotated = hw.helixplot(df_wt_rotated.iloc[ft1:lt1], legend=False, first_pos=first_pos)

wt_plot_2 = hw.helixplot(df_wt.iloc[ft2:], legend=False, first_pos=first_pos)

wt_plot_2_rotated = hw.helixplot(df_wt_rotated.iloc[ft2:], legend=False, first_pos=first_pos)


# 2. Mutant AAP2
# Entire helix
pm_plot_1 = hw.helixplot(df_pm, first_pos=first_pos, makebold=True)
# Two individual plots figure assembly
pm_plot_1 = hw.helixplot(df_pm.iloc[0:10], legend=False, makebold=True, first_pos=first_pos)

pm_plot_1_rotated = hw.helixplot(df_pm_rotated.iloc[0:10], legend=False, makebold=True, first_pos=first_pos)

pm_plot_2 = hw.helixplot(df_pm.iloc[10:], legend=False, makebold=True, first_pos=first_pos)

pm_plot_2_rotated = hw.helixplot(df_pm_rotated.iloc[10:], legend=False, makebold=True, first_pos=first_pos)
# Out:
# Rotating helix by 180 degrees (counter-clockwise)!
# Rotating helix by 180 degrees (counter-clockwise)!
# Sequence length exceeds 18 residues. Dividing into 2 wheels.
# Sequence length exceeds 18 residues. Dividing into 2 wheels.
