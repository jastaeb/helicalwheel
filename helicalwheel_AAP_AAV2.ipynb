# %%
try:
    import helicalwheel as hw
except ImportError:
    # !pip install helicalwheel
    import helicalwheel as hw
    print("helicalwheel package installed. Please restart the kernel to use it.")
# Out:
# Collecting helicalwheel
#   Using cached helicalwheel-0.1.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from helicalwheel) (2.3.5)
# Requirement already satisfied: pandas in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from helicalwheel) (2.3.3)
# Requirement already satisfied: matplotlib in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from helicalwheel) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from matplotlib->helicalwheel) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->helicalwheel) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from pandas->helicalwheel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jann/miniforge3/envs/py313/lib/python3.13/site-packages (from pandas->helicalwheel) (2025.3)
# Using cached helicalwheel-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: helicalwheel
# Successfully installed helicalwheel-0.1.2
# helicalwheel package installed. Please restart the kernel to use it.

# %%
# %% Inputting the sequences  
aap2_seq_wt = "LVWELIRWLQAVAHQWQTIT"
aap2_seq_pm = "AAAEAARAAQAAAHQAQTAT" 


# Check that sequences are of the same length
if len(aap2_seq_wt) != len(aap2_seq_pm):
    raise ValueError("Wild-type and mutant sequences must be of the same length.")
else:
    mut_res = [i != y for i, y in zip(aap2_seq_wt, aap2_seq_pm)]

# %% Creating dataframes with helix coordinates
df_wt=hw.helix_coordinates(aap2_seq_wt)
df_wt_rotated=hw.helix_coordinates(aap2_seq_wt, rotate_deg=180)
df_pm=hw.helix_coordinates(aap2_seq_pm)
df_pm_rotated=hw.helix_coordinates(aap2_seq_pm, rotate_deg=180)

# Adding mutation information to the dataframes
df_wt["mutated"]=mut_res
df_pm["mutated"]=mut_res

#%% Plotting the helical wheels
first_pos = 20 # position in total protein sequence of first helical residue 

# 1. Wild-type AAP2
# Entire helix
wt_plot_1 = hw.helixplot(df_wt, first_pos=first_pos)
# Two individual plots figure assembly
wt_plot_1 = hw.helixplot(df_wt.iloc[0:10], legend=False, first_pos=first_pos)
wt_plot_1_rotated = hw.helixplot(df_wt_rotated.iloc[0:10], legend=False, first_pos=first_pos)
wt_plot_2 = hw.helixplot(df_wt.iloc[10:], legend=False, first_pos=first_pos)
wt_plot_2_rotated = hw.helixplot(df_wt_rotated.iloc[10:], legend=False, first_pos=first_pos)

# 2. Mutant AAP2
# Entire helix
pm_plot_1 = hw.helixplot(df_pm, first_pos=first_pos, makebold=True)
# Two individual plots figure assembly
pm_plot_1 = hw.helixplot(df_pm.iloc[0:10], legend=False, makebold=True, first_pos=first_pos)
pm_plot_1_rotated = hw.helixplot(df_pm_rotated.iloc[0:10], legend=False, makebold=True, first_pos=first_pos)
pm_plot_2 = hw.helixplot(df_pm.iloc[10:], legend=False, makebold=True, first_pos=first_pos)
pm_plot_2_rotated = hw.helixplot(df_pm_rotated.iloc[10:], legend=False, makebold=True, first_pos=first_pos)
# Out:
# Rotating helix by 180 degrees (counter-clockwise)!
# Rotating helix by 180 degrees (counter-clockwise)!
# Sequence length exceeds 18 residues. Dividing into 2 wheels.
# Sequence length exceeds 18 residues. Dividing into 2 wheels.
