# %% [markdown]
# Installation

# %%
! pip install -e .
# Out:
# Obtaining file:///Volumes/g_vsf_virologie%24/Virologie/Cathy/Jann/251110_AAP_helix_top_view/251215_helicalwheel/publish
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from helicalwheel_jstaeb==0.1.0) (2.3.5)
# Requirement already satisfied: pandas in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from helicalwheel_jstaeb==0.1.0) (2.3.3)
# Requirement already satisfied: matplotlib in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from helicalwheel_jstaeb==0.1.0) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from matplotlib->helicalwheel_jstaeb==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->helicalwheel_jstaeb==0.1.0) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from pandas->helicalwheel_jstaeb==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jann/miniforge3/envs/helicalwheel/lib/python3.14/site-packages (from pandas->helicalwheel_jstaeb==0.1.0) (2025.3)
# Building wheels for collected packages: helicalwheel_jstaeb
#   Building editable for helicalwheel_jstaeb (pyproject.toml) ... done
#   Created wheel for helicalwheel_jstaeb: filename=helicalwheel_jstaeb-0.1.0-0.editable-py3-none-any.whl size=1565 sha256=85f073595823b1c5dfa69fa11c9a8c538a3ac87634f69b543cf9638b85d43cfc
#   Stored in directory: /private/var/folders/kc/_lssg0zx0dbcvgb9v6pdpm300000gn/T/pip-ephem-wheel-cache-wow1qxsp/wheels/91/3c/aa/087098f91fd24fae0624f6ec134938b8925323b47b73491cf9
# Successfully built helicalwheel_jstaeb
# Installing collected packages: helicalwheel_jstaeb
#   Attempting uninstall: helicalwheel_jstaeb
#     Found existing installation: helicalwheel_jstaeb 0.1.0
#     Uninstalling helicalwheel_jstaeb-0.1.0:
#       Successfully uninstalled helicalwheel_jstaeb-0.1.0
# Successfully installed helicalwheel_jstaeb-0.1.0

# %% [markdown]
# Import the helical wheel package.

# %%
import helicalwheel as hw

# %%
aap2_seq_wt = "LVWELIRWLQAVAHQWQTIT"
aap2_seq_pm = "AAAEAARAAQAAAHQAQTAT" 

if len(aap2_seq_wt) != len(aap2_seq_pm):
    raise ValueError("Wild-type and mutant sequences must be of the same length.")
else:
    mut_res = [i != y for i, y in zip(aap2_seq_wt, aap2_seq_pm)]



df_wt=hw.helix_coordinates(aap2_seq_wt)
#df_pm=hw.helix_coordinates(aap2_seq_pm)


df_wt["mutated"]=mut_res
#df_pm["mutated"]=mut_res


wt_plot_1 = hw.helixplot(df_pm.iloc[0:20])
# Out:
# Sequence length exceeds 18 residues. Dividing into 2 wheels.
